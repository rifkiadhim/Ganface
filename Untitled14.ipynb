# %% [markdown]
# <a href="https://colab.research.google.com/github/rifkiadhim/Ganface/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts imageio imageio[ffmpeg] scikit-image ffmpeg-python

# Clone the First Order Motion Model repository
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# %cd first-order-model
# Out:
# ...
# Cloning into 'first-order-model'...
# remote: Enumerating objects: 393, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 393 (delta 41), reused 66 (delta 38), pack-reused 312
# Receiving objects: 100% (393/393), 72.19 MiB | 43.28 MiB/s, done.
# Resolving deltas: 100% (204/204), done.
# /content/first-order-model

# %%
from gtts import gTTS
import IPython.display as ipd

def text_to_speech(text):
    tts = gTTS(text=text, lang='en')
    tts.save('output_audio.mp3')
    return 'output_audio.mp3'

# Convert text to speech
audio_path = text_to_speech("Haloo saya orang jawa timur")
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import imageio
from skimage.transform import resize
from demo import load_checkpoints, make_animation

def load_image(image_path):
    img = imageio.imread(image_path)
    img = resize(img, (256, 256))[..., :3]
    return img

def load_video(video_path):
    video = imageio.mimread(video_path, memtest=False)
    video = [resize(frame, (256, 256))[..., :3] for frame in video]
    return video

def animate_image(source_image_path, driving_video_path, model_path='/content/drive/MyDrive/vox-cpk.pth.tar'):
    source_image = load_image(source_image_path)
    driving_video = load_video(driving_video_path)

    generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', checkpoint_path=model_path)

    predictions = make_animation(source_image, driving_video, generator, kp_detector)
    output_path = 'animated_output.mp4'
    imageio.mimsave(output_path, predictions, fps=30)
    return output_path

# Animate the image using the driving video
output_video_path = animate_image('/content/AhmadDahlan.jpg', '/content/drive/MyDrive/genvid.mp4')
# Out:
# <ipython-input-3-73b6b42350d3>:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(image_path)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-73b6b42350d3> in <cell line: 27>()
#      25
#      26 # Animate the image using the driving video
# ---> 27 output_video_path = animate_image('/content/AhmadDahlan.jpg', '/content/drive/MyDrive/genvid.mp4')
#
# <ipython-input-3-73b6b42350d3> in animate_image(source_image_path, driving_video_path, model_path)
#      14
#      15 def animate_image(source_image_path, driving_video_path, model_path='/content/drive/MyDrive/vox-cpk.pth.tar'):
# ---> 16     source_image = load_image(source_image_path)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

def display_video(video_path):
    video_file = open(video_path, "rb").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
    return HTML(f"""<video width=400 controls><source src="{video_url}"></video>""")

# Display the resulting animated video
display_video(output_video_path)
# Out:
# <video width=400 controls><source src="data:video/mp4;base64,..."></video>

# %%
# Step 1: Install dependencies
# !pip install gtts imageio imageio[ffmpeg] scikit-image ffmpeg-python
# !apt-get install ffmpeg

# Clone the First Order Motion Model repository
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# %cd first-order-model


# Step 2: Convert text to speech
from gtts import gTTS
import IPython.display as ipd

def text_to_speech(text):
    tts = gTTS(text=text, lang='en')
    tts.save('output_audio.mp3')
    return 'output_audio.mp3'

# Get text input from the user
text = input("Enter the text you want the animated character to say: ")
audio_path = text_to_speech(text)
ipd.Audio(audio_path)

# Step 3: Load image and video
import imageio
from skimage.transform import resize
from demo import load_checkpoints, make_animation

def load_image(image_path):
    img = imageio.imread(image_path)
    img = resize(img, (256, 256))[..., :3]
    return img

def load_video(video_path):
    video = imageio.mimread(video_path, memtest=False)
    video = [resize(frame, (256, 256))[..., :3] for frame in video]
    return video

def animate_image(source_image_path, driving_video_path, model_path='/content/drive/MyDrive/vox-cpk.pth.tar'):
    source_image = load_image(source_image_path)
    driving_video = load_video(driving_video_path)

    generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', checkpoint_path=model_path)

    predictions = make_animation(source_image, driving_video, generator, kp_detector)
    output_path = 'animated_output.mp4'
    imageio.mimsave(output_path, predictions, fps=30)
    return output_path

output_video_path = animate_image('/content/AhmadDahlan.jpg', '/content/drive/MyDrive/genvid.mp4')

# Step 4: Combine audio and video
import subprocess

def combine_audio_video(video_path, audio_path, output_path):
    command = f"ffmpeg -i {video_path} -i {audio_path} -c:v copy -c:a aac -strict experimental {output_path}"
    subprocess.call(command, shell=True)

combine_audio_video('animated_output.mp4', 'output_audio.mp3', 'final_output.mp4')

# Step 5: Display and download the final video
from IPython.display import HTML
from base64 import b64encode

def display_video(video_path):
    video_file = open(video_path, "rb").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
    return HTML(f"""<video width=400 controls><source src="{video_url}"></video>""")

display_video('final_output.mp4')

from google.colab import files
files.download('final_output.mp4')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Cloning into 'first-order-model'...
# remote: Enumerating objects: 393, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 393 (delta 41), reused 66 (delta 38), pack-reused 312
# Receiving objects: 100% (393/393), 72.19 MiB | 41.93 MiB/s, done.
# Resolving deltas: 100% (204/204), done.
# /content/first-order-model/first-order-model
# Enter the text you want the animated character to say: saya mau makan nasi kambing
# ...

# %%
# Step 1: Install dependencies
# !pip install gtts imageio imageio[ffmpeg] scikit-image ffmpeg-python pydub
# !apt-get install ffmpeg

# Clone the First Order Motion Model repository
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# %cd first-order-model


# Step 2: Convert text to speech
from gtts import gTTS
import IPython.display as ipd
import os
from pydub import AudioSegment

def text_to_speech(text):
    tts = gTTS(text=text, lang='id')
    tts.save('output_audio.mp3')
    return 'output_audio.mp3'

# Get text input from the user
text = input("Enter the text you want the animated character to say: ")
audio_path = text_to_speech(text)
ipd.Audio(audio_path)

# Get audio duration in seconds
audio = AudioSegment.from_file(audio_path)
audio_duration = len(audio) / 1000  # pydub works in milliseconds

# Step 3: Load image and video
import imageio
from skimage.transform import resize
from demo import load_checkpoints, make_animation

def load_image(image_path):
    img = imageio.imread(image_path)
    img = resize(img, (256, 256))[..., :3]
    return img

def load_video(video_path):
    video = imageio.mimread(video_path, memtest=False)
    video = [resize(frame, (256, 256))[..., :3] for frame in video]
    return video

def animate_image(source_image_path, driving_video_path, audio_duration, model_path='/content/drive/MyDrive/vox-cpk.pth.tar'):
    source_image = load_image(source_image_path)
    driving_video = load_video(driving_video_path)

    # Calculate the number of frames needed to match the audio duration
    fps = 30
    num_frames = int(fps * audio_duration)
    driving_video = driving_video[:num_frames]  # Trim or extend the driving video to match the audio duration

    generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', checkpoint_path=model_path)

    predictions = make_animation(source_image, driving_video, generator, kp_detector)
    output_path = 'animated_output.mp4'
    imageio.mimsave(output_path, predictions, fps=fps)
    return output_path

output_video_path = animate_image('/content/AhmadDahlan.jpg', '/content/trial.mp4', audio_duration)

# Step 4: Combine audio and video
import subprocess

def combine_audio_video(video_path, audio_path, output_path):
    command = f"ffmpeg -i {video_path} -i {audio_path} -c:v copy -c:a aac -strict experimental {output_path}"
    subprocess.call(command, shell=True)

combine_audio_video('animated_output.mp4', 'output_audio.mp3', 'final_output.mp4')

# Step 5: Display and download the final video
from IPython.display import HTML
from base64 import b64encode

def display_video(video_path):
    video_file = open(video_path, "rb").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
    return HTML(f"""<video width=400 controls><source src="{video_url}"></video>""")

display_video('final_output.mp4')

from google.colab import files
files.download('final_output.mp4')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Cloning into 'first-order-model'...
# remote: Enumerating objects: 393, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 393 (delta 41), reused 65 (delta 38), pack-reused 312
# Receiving objects: 100% (393/393), 72.19 MiB | 9.27 MiB/s, done.
# Resolving deltas: 100% (203/203), done.
# /content/first-order-model/first-order-model/first-order-model/first-order-model/first-order-model/first-order-model
# Enter the text you want the animated character to say: Halo nama saya bapak ahmad dahlan, saya pendiri muhammadiyah
# ...

# %%
# !pip install Flask gtts imageio scikit-image ffmpeg-python pydub
# !apt-get install ffmpeg
# !pip install flask-ngrok
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...

# %%
# Step 1: Install dependencies
# !pip install gtts imageio imageio[ffmpeg] scikit-image ffmpeg-python pydub
# !apt-get install ffmpeg

# Clone the First Order Motion Model repository
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# %cd first-order-model


# Step 2: Convert text to speech
from gtts import gTTS
import IPython.display as ipd
import os
from pydub import AudioSegment

def text_to_speech(text):
    tts = gTTS(text=text, lang='id')
    tts.save('output_audio.mp3')
    return 'output_audio.mp3'

# Get text input from the user
text = input("Masukan Text: ")
audio_path = text_to_speech(text)
ipd.Audio(audio_path)

# Get audio duration in seconds
audio = AudioSegment.from_file(audio_path)
audio_duration = len(audio) / 1000  # pydub works in milliseconds

# Step 3: Load image and video
import imageio
from skimage.transform import resize
from demo import load_checkpoints, make_animation

def load_image(image_path):
    img = imageio.imread(image_path)
    img = resize(img, (256, 256))[..., :3]
    return img

def load_video(video_path):
    video = imageio.mimread(video_path, memtest=False)
    video = [resize(frame, (256, 256))[..., :3] for frame in video]
    return video

def animate_image(source_image_path, driving_video_path, audio_duration, model_path='/content/drive/MyDrive/vox-cpk.pth.tar'):
    source_image = load_image(source_image_path)
    driving_video = load_video(driving_video_path)

    # Calculate the number of frames needed to match the audio duration
    fps = 30
    num_frames = int(fps * audio_duration)
    driving_video = driving_video[:num_frames]  # Trim or extend the driving video to match the audio duration

    generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', checkpoint_path=model_path)

    predictions = make_animation(source_image, driving_video, generator, kp_detector)
    output_path = 'animated_output.mp4'
    imageio.mimsave(output_path, predictions, fps=fps)
    return output_path

output_video_path = animate_image('/content/AhmadDahlan.jpg', '/content/trial.mp4', audio_duration)

# Step 4: Combine audio and video
import subprocess

def combine_audio_video(video_path, audio_path, output_path):
    command = f"ffmpeg -i {video_path} -i {audio_path} -c:v copy -c:a aac -strict experimental {output_path}"
    subprocess.call(command, shell=True)

combine_audio_video('animated_output.mp4', 'output_audio.mp3', 'final_output.mp4')

# Step 5: Display and download the final video
from IPython.display import HTML
from base64 import b64encode

def display_video(video_path):
    video_file = open(video_path, "rb").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
    return HTML(f"""<video width=400 controls><source src="{video_url}"></video>""")

display_video('final_output.mp4')

from google.colab import files
files.download('final_output.mp4')

# %%
# Step 1: Install dependencies
# !pip install gtts imageio imageio[ffmpeg] scikit-image ffmpeg-python pydub
# !apt-get install ffmpeg

# Clone the First Order Motion Model repository
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# %cd first-order-model



# Step 2: Convert text to speech
from gtts import gTTS
import IPython.display as ipd
import os
from pydub import AudioSegment

def text_to_speech(text):
    tts = gTTS(text=text, lang='id')
    tts.save('output_audio.mp3')
    return 'output_audio.mp3'

# Get text input from the user
text = input("Enter the text you want the animated character to say: ")
audio_path = text_to_speech(text)
ipd.Audio(audio_path)

# Get audio duration in seconds
audio = AudioSegment.from_file(audio_path)
audio_duration = len(audio) / 1000  # pydub works in milliseconds

# Step 3: Load image and video
import imageio
from skimage.transform import resize
from demo import load_checkpoints, make_animation

def load_image(image_path):
    img = imageio.imread(image_path)
    img = resize(img, (256, 256))[..., :3]
    return img

def load_video(video_path):
    video = imageio.mimread(video_path, memtest=False)
    video = [resize(frame, (256, 256))[..., :3] for frame in video]
    return video

def animate_image(source_image_path, driving_video_path, audio_duration, model_path='/content/drive/MyDrive/vox-cpk.pth.tar'):
    source_image = load_image(source_image_path)
    driving_video = load_video(driving_video_path)

    # Calculate the number of frames needed to match the audio duration
    fps = 30
    num_frames = int(fps * audio_duration)
    driving_video = driving_video[:num_frames]  # Trim or extend the driving video to match the audio duration

    generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', checkpoint_path=model_path)

    predictions = make_animation(source_image, driving_video, generator, kp_detector)
    output_path = 'animated_output.mp4'
    imageio.mimsave(output_path, predictions, fps=fps)
    return output_path

output_video_path = animate_image('/content/AhmadDahlan.jpg', '/content/drive/MyDrive/genvid.mp4', audio_duration)

# Step 4: Combine audio and video
import subprocess

def combine_audio_video(video_path, audio_path, output_path):
    command = f"ffmpeg -i {video_path} -i {audio_path} -c:v copy -c:a aac -strict experimental {output_path}"
    subprocess.call(command, shell=True)

combine_audio_video('animated_output.mp4', 'output_audio.mp3', 'final_output.mp4')

# Step 5: Display and download the final video
from IPython.display import HTML
from base64 import b64encode

def display_video(video_path):
    video_file = open(video_path, "rb").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
    return HTML(f"""<video width=400 controls><source src="{video_url}"></video>""")

display_video('final_output.mp4')

from google.colab import files
files.download('final_output.mp4')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# fatal: destination path 'first-order-model' already exists and is not an empty directory.
# /content/first-order-model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-589db5a6812a> in <cell line: 23>()
#      21
#      22 # Get text input from the user
# ---> 23 text = input("Enter the text you want the animated character to say: ")
#      24 audio_path = text_to_speech(text)
#      25 ipd.Audio(audio_path)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# ...
